# %%
import pandas as pd
import numpy as np
from scipy import stats
import psycopg2
from sklearn.model_selection import train_test_split
import warnings
import random
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # SVM

# %%
X_train= pd.read_csv("X_Train.csv")
X_test= pd.read_csv("X_test.csv")
y_train= pd.read_csv("y_train.csv")
y_test= pd.read_csv("y_test.csv")

# %%
from sklearn.svm import SVC

# %% [markdown]
# ### Kernel= linear | Cost parameter = 1.0

# %%
model=SVC(C=1.0, kernel='linear')
                            
model.fit(X_train, y_train)

# Model predict
y_pred=model.predict(X_test)

# Confusion matrix
print(classification_report(y_test,y_pred))

# Plot Confusion Matrix
print("\nThe confusion matrix is:")
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cnf_matrix, annot=True, cmap='Blues', fmt='g', xticklabels=y_test.unique(), yticklabels=y_test.unique())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# d:\Jupyter\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#               precision    recall  f1-score   support
#
#         High       0.58      0.05      0.09      5653
#          Low       0.73      0.99      0.84     14580
#
#     accuracy                           0.72     20233
#    macro avg       0.65      0.52      0.46     20233
# weighted avg       0.69      0.72      0.63     20233
#
#
# The confusion matrix is:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 15
#      13 cnf_matrix = confusion_matrix(y_test, y_pred)
#      14 plt.figure(figsize=(8, 6))
# ...

# %%
# Plot Confusion Matrix
print("\nThe confusion matrix is:")
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cnf_matrix, annot=True, cmap='Blues', fmt='g', xticklabels=y_test.Demand_Ctg.unique(), yticklabels=y_test.Demand_Ctg.unique())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# The confusion matrix is:

# %% [markdown]
# ### Kernel= poly with degree 3 | Cost parameter = 10.0

# %%
model2=SVC(C=10.0, kernel='poly', degree=3)
                            
model2.fit(X_train, y_train)

# Model predict
y_pred=model2.predict(X_test)

# Confusion matrix
print(classification_report(y_test,y_pred))

# Plot Confusion Matrix
print("\nThe confusion matrix is:")
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cnf_matrix, annot=True, cmap='Blues', fmt='g', xticklabels=y_test.Demand_Ctg.unique(), yticklabels=y_test.Demand_Ctg.unique())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# d:\Jupyter\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Jupyter\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Jupyter\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ### Kernel= RBF with gamma as scale | Cost parameter = 5.0

# %%
model3=SVC(C=5.0, kernel='rbf', gamma="scale")
                            
model3.fit(X_train, y_train)

# Model predict
y_pred=model3.predict(X_test)

# Confusion matrix
print(classification_report(y_test,y_pred))

# Plot Confusion Matrix
print("\nThe confusion matrix is:")
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cnf_matrix, annot=True, cmap='Blues', fmt='g', xticklabels=y_test.Demand_Ctg.unique(), yticklabels=y_test.Demand_Ctg.unique())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# d:\Jupyter\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Jupyter\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Jupyter\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
X_train.shape
# Out:
# (41079, 23)

# %%
model4=SVC(C=1000.0, kernel='rbf', gamma='scale')
                            
model4.fit(X_train[:10000], y_train[:10000])

# Model predict
y_pred=model4.predict(X_test[:10000])

# Confusion matrix
print(classification_report(y_test[:10000],y_pred[:10000]))

# Plot Confusion Matrix
print("\nThe confusion matrix is:")
cnf_matrix = confusion_matrix(y_test[:10000], y_pred[:10000])
plt.figure(figsize=(8, 6))
sns.heatmap(cnf_matrix, annot=True, cmap='Blues', fmt='g', xticklabels=y_test.Demand_Ctg.unique(), yticklabels=y_test.Demand_Ctg.unique())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# d:\Jupyter\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#               precision    recall  f1-score   support
#
#         High       0.55      0.17      0.25      2799
#          Low       0.74      0.95      0.83      7201
#
#     accuracy                           0.73     10000
#    macro avg       0.65      0.56      0.54     10000
# weighted avg       0.69      0.73      0.67     10000
#
#
# The confusion matrix is:

# %%
model4=SVC(C=500.0, kernel='poly', degree=3)
                            
model4.fit(X_train[:10000], y_train[:10000])

# Model predict
y_pred=model4.predict(X_test[:10000])

# Confusion matrix
print(classification_report(y_test[:10000],y_pred[:10000]))

# Plot Confusion Matrix
print("\nThe confusion matrix is:")
cnf_matrix = confusion_matrix(y_test[:10000], y_pred[:10000])
plt.figure(figsize=(8, 6))
sns.heatmap(cnf_matrix, annot=True, cmap='Blues', fmt='g', xticklabels=y_test.Demand_Ctg.unique(), yticklabels=y_test.Demand_Ctg.unique())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# d:\Jupyter\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\Jupyter\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Jupyter\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#         High       0.00      0.00      0.00      2799
# ...

# %%
model4=SVC(C=500.0, kernel='poly', degree=5)
                            
model4.fit(X_train[:1000], y_train[:1000])

# Model predict
y_pred=model4.predict(X_test[:1000])

# Confusion matrix
print(classification_report(y_test[:1000],y_pred[:1000]))

# Plot Confusion Matrix
print("\nThe confusion matrix is:")
cnf_matrix = confusion_matrix(y_test[:1000], y_pred[:1000])
plt.figure(figsize=(8, 6))
sns.heatmap(cnf_matrix, annot=True, cmap='Blues', fmt='g', xticklabels=y_test.Demand_Ctg.unique(), yticklabels=y_test.Demand_Ctg.unique())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# d:\Jupyter\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#               precision    recall  f1-score   support
#
#         High       0.00      0.00      0.00       282
#          Low       0.72      0.99      0.83       718
#
#     accuracy                           0.71      1000
#    macro avg       0.36      0.50      0.42      1000
# weighted avg       0.51      0.71      0.60      1000
#
#
# The confusion matrix is:
